# %%
import tensorflow as tf
import time
import cupy as cp
import numpy as np
c=tf.rand(10000,300).cuda()
d=tf.rand(300,10000).cuda()

# %%
start=time.time()
for j in range(50):
    print(j)
    for i in range(100):
        #print(i,time.time()-start)
        a=torch.mm(c,d)
    print(time.time()-start)
# Out:
# 0
# 0.003284454345703125
# 1
# 0.005891323089599609
# 2
# 0.007838249206542969
# 3
# 0.009590387344360352
# 4
# 0.011307239532470703
# 5
# 0.012984514236450195
# 6
# 0.014616250991821289
# 7
# 0.015978336334228516
# 8
# 0.017385482788085938
# 9
# 0.01875162124633789
# 10
# 0.5423557758331299
# 11
# 1.2408339977264404
# 12
# 1.9367396831512451
# 13
# 2.634047746658325
# 14
# 3.3312971591949463
# 15
# 4.027429580688477
# 16
# 4.724188804626465
# 17
# 5.421095609664917
# 18
# 6.1171348094940186
# 19
# 6.813928842544556
# 20
# 7.510760068893433
# 21
# 8.207013130187988
# 22
# 8.904083728790283
# 23
# 9.600795030593872
# 24
# 10.297130584716797
# 25
# 10.994314193725586
# 26
# 11.691046953201294
# 27
# 12.387642621994019
# 28
# 13.084490776062012
# 29
# 13.781455993652344
# 30
# 14.477949857711792
# 31
# 15.174558639526367
# 32
# 15.87171459197998
# 33
# 16.568317890167236
# 34
# 17.264833211898804
# 35
# 17.961994647979736
# 36
# 18.658857107162476
# 37
# 19.355546712875366
# 38
# ...
